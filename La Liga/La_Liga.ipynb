# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path = 'La Liga/SP1.csv'

# Cargar el archivo CSV
df = pd.read_csv(file_path, sep=",")

# Mostrar las primeras filas del datas
print(df.shape)
df.sample(10)
# Out:
# (380, 105)
#      Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 150  SP1  09/12/2023  13:00      Alaves   Las Palmas     0     1   A     0
# 219  SP1  01/02/2024  20:00      Getafe  Real Madrid     0     2   A     0
# 119  SP1  10/11/2023  20:00  Ath Bilbao        Celta     4     3   H     2
# 189  SP1  04/01/2024  20:30  Las Palmas    Barcelona     1     2   A     1
# 122  SP1  11/11/2023  17:30     Granada       Getafe     1     1   D     1
# 379  SP1  26/05/2024  20:00     Sevilla    Barcelona     1     2   A     1
# 306  SP1  14/04/2024  15:15     Granada       Alaves     2     0   H     2
# 327  SP1  28/04/2024  17:30  Villarreal    Vallecano     3     0   H     1
# 132  SP1  25/11/2023  20:00  Ath Madrid     Mallorca     1     0   H     0
# 254  SP1  25/02/2024  13:00       Cadiz        Celta     2     2   D     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path1 = 'La Liga/SP1 (1).csv'

# Cargar el archivo CSV
df1 = pd.read_csv(file_path1, sep=",")

# Mostrar las primeras filas del datas
print(df1.shape)
df1.sample(10)
# Out:
# (380, 105)
#      Div        Date   Time     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 116  SP1  30/10/2022  15:15  Real Madrid      Girona     1     1   D     0
# 338  SP1  14/05/2023  20:00      Espanol   Barcelona     2     4   A     0
# 361  SP1  28/05/2023  18:00      Almeria  Valladolid     0     0   D     0
# 306  SP1  26/04/2023  21:00    Vallecano   Barcelona     2     1   H     1
# 16   SP1  21/08/2022  18:30   Ath Madrid  Villarreal     0     2   A     0
# 257  SP1  19/03/2023  15:15     Sociedad       Elche     2     0   H     0
# 337  SP1  14/05/2023  17:30   Valladolid     Sevilla     0     3   A     0
# 13   SP1  20/08/2022  18:30     Mallorca       Betis     1     2   A     0
# 196  SP1  05/02/2023  15:15       Girona    Valencia     1     0   H     0
# 291  SP1  22/04/2023  13:00      Osasuna       Betis     3     2   H     3
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path2 = 'La Liga/SP1 (2).csv'

# Cargar el archivo CSV
df2 = pd.read_csv(file_path2, sep=",")

# Mostrar las primeras filas del datas
print(df2.shape)
df2.sample(10)
# Out:
# (380, 105)
#      Div        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 361  SP1  15/05/2022  18:30  Ath Bilbao     Osasuna     2     0   H     1
# 200  SP1  10/01/2022  20:00     Espanol       Elche     1     2   A     1
# 9    SP1  16/08/2021  21:00       Elche  Ath Bilbao     0     0   D     0
# 150  SP1  04/12/2021  17:30  Ath Madrid    Mallorca     1     2   A     0
# 277  SP1  13/03/2022  20:00   Barcelona     Osasuna     4     0   H     3
# 311  SP1  16/04/2022  15:15      Alaves   Vallecano     1     0   H     0
# 169  SP1  18/12/2021  15:15    Sociedad  Villarreal     1     3   A     1
# 327  SP1  21/04/2022  19:00       Cadiz  Ath Bilbao     2     3   A     0
# 235  SP1  13/02/2022  20:00     Espanol   Barcelona     2     2   D     1
# 355  SP1  11/05/2022  19:30     Sevilla    Mallorca     0     0   D     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path3 = 'La Liga/SP1 (3).csv'

# Cargar el archivo CSV
df3 = pd.read_csv(file_path3, sep=",")

# Mostrar las primeras filas del datas
print(df3.shape)
df3.sample(10)
# Out:
# (380, 105)
#      Div        Date   Time     HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  \
# 305  SP1  18/04/2021  17:30        Cadiz     Celta     0     0   D     0
# 41   SP1  04/10/2020  17:30        Cadiz   Granada     1     1   D     0
# 89   SP1  22/11/2020  15:15        Cadiz  Sociedad     0     1   A     0
# 57   SP1  24/10/2020  20:00   Ath Madrid     Betis     2     0   H     0
# 236  SP1  22/02/2021  20:00      Osasuna   Sevilla     0     2   A     0
# 6    SP1  13/09/2020  20:00     Valencia   Levante     4     2   H     2
# 278  SP1  21/03/2021  17:30   Ath Madrid    Alaves     1     0   H     0
# 329  SP1  29/04/2021  18:00    Barcelona   Granada     1     2   A     1
# 302  SP1  18/04/2021  15:15       Alaves    Huesca     1     0   H     0
# 348  SP1  09/05/2021  20:00  Real Madrid   Sevilla     2     2   D     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path4 = 'La Liga/SP1 (4).csv'

# Cargar el archivo CSV
df4 = pd.read_csv(file_path4, sep=",")

# Mostrar las primeras filas del datas
print(df4.shape)
df4.sample(10)
# Out:
# (380, 105)
#      Div        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 245  SP1  23/02/2020  13:00      Alaves  Ath Bilbao     2     1   H     1
# 154  SP1  08/12/2019  11:00       Eibar      Getafe     0     1   A     0
# 65   SP1  29/09/2019  11:00     Espanol  Valladolid     0     2   A     0
# 216  SP1  02/02/2020  15:00  Ath Bilbao      Getafe     0     2   A     0
# 50   SP1  24/09/2019  18:00  Valladolid     Granada     1     1   D     1
# 304  SP1  23/06/2020  21:00   Barcelona  Ath Bilbao     1     0   H     0
# 240  SP1  22/02/2020  12:00       Celta     Leganes     1     0   H     0
# 109  SP1  02/11/2019  12:00     Espanol    Valencia     1     2   A     1
# 136  SP1  24/11/2019  15:00       Eibar      Alaves     0     2   A     0
# 129  SP1  22/11/2019  20:00     Levante    Mallorca     2     1   H     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
# Concatenar los DataFrames
la_liga = pd.concat([df,df1, df2, df3, df4])
print(la_liga.shape)
la_liga.sample(10)
# Out:
# (1900, 105)
#      Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 255  SP1  25/02/2024  15:15        Betis   Ath Bilbao     3     1   H     2
# 5    SP1  14/08/2022  18:30     Valencia       Girona     1     0   H     1
# 84   SP1  19/10/2019  20:00     Mallorca  Real Madrid     1     0   H     1
# 278  SP1  21/03/2021  17:30   Ath Madrid       Alaves     1     0   H     0
# 198  SP1  19/01/2020  17:30   Ath Bilbao        Celta     1     1   D     0
# 185  SP1  03/01/2024  18:15  Real Madrid     Mallorca     1     0   H     0
# 287  SP1  17/06/2020  21:00      Osasuna   Ath Madrid     0     5   A     0
# 121  SP1  09/11/2019  15:00     Valencia      Granada     2     0   H     0
# 341  SP1  07/07/2020  21:00        Celta   Ath Madrid     1     1   D     0
# 24   SP1  31/08/2019  18:00      Levante   Valladolid     2     0   H     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
# Guardar como CSV
la_liga.to_csv('la_liga.csv', index=False)
