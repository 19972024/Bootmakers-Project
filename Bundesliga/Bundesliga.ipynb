# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path = 'Bundesliga/D1.csv'

# Cargar el archivo CSV
df = pd.read_csv(file_path, sep=",")

# Mostrar las primeras filas del datas
print(df.shape)
df.sample(10)
# Out:
# (306, 105)
#     Div        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 266  D1  20/04/2024  17:30   Union Berlin  Bayern Munich     1     5   A
# 14   D1  26/08/2023  14:30     Heidenheim     Hoffenheim     2     3   A
# 114  D1  03/12/2023  16:30     Leverkusen       Dortmund     1     1   D
# 189  D1  16/02/2024  19:30        FC Koln  Werder Bremen     0     1   A
# 187  D1  11/02/2024  14:30      Stuttgart          Mainz     3     1   H
# 229  D1  16/03/2024  14:30   Union Berlin  Werder Bremen     2     1   H
# 287  D1  05/05/2024  18:30     Heidenheim          Mainz     1     1   D
# 84   D1  04/11/2023  14:30     Hoffenheim     Leverkusen     2     3   A
# 15   D1  26/08/2023  17:30     M'gladbach     Leverkusen     0     3   A
# 105  D1  25/11/2023  17:30  Ein Frankfurt      Stuttgart     1     2   A
#
#      HTHG  HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path1 = 'Bundesliga/D1 (1).csv'

# Cargar el archivo CSV
df1 = pd.read_csv(file_path1, sep=",")

# Mostrar las primeras filas del datas
print(df1.shape)
df1.sample(10)
# Out:
# (306, 105)
#     Div        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 209  D1  11/03/2023  14:30  Ein Frankfurt      Stuttgart     1     1   D
# 214  D1  12/03/2023  16:30  Werder Bremen     Leverkusen     2     3   A
# 234  D1  08/04/2023  14:30       Augsburg        FC Koln     1     3   A
# 291  D1  20/05/2023  14:30     Schalke 04  Ein Frankfurt     2     2   D
# 87   D1  16/10/2022  14:30        FC Koln       Augsburg     3     2   H
# 152  D1  25/01/2023  19:30  Werder Bremen   Union Berlin     1     2   A
# 55   D1  17/09/2022  14:30       Augsburg  Bayern Munich     1     0   H
# 106  D1  30/10/2022  16:30     Schalke 04       Freiburg     0     2   A
# 189  D1  24/02/2023  19:30          Mainz     M'gladbach     4     0   H
# 91   D1  22/10/2022  14:30       Augsburg     RB Leipzig     3     3   D
#
#      HTHG  HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path2 = 'Bundesliga/D1 (2).csv'

# Cargar el archivo CSV
df2 = pd.read_csv(file_path2, sep=",")

# Mostrar las primeras filas del datas
print(df2.shape)
df2.sample(10)
# Out:
# (306, 105)
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 167  D1  15/01/2022  14:30       Wolfsburg          Hertha     0     0   D
# 263  D1  16/04/2022  14:30        Freiburg          Bochum     3     0   H
# 74   D1  23/10/2021  14:30       Bielefeld        Dortmund     1     3   A
# 158  D1  08/01/2022  14:30      RB Leipzig           Mainz     4     1   H
# 58   D1  02/10/2021  14:30       Wolfsburg      M'gladbach     1     3   A
# 210  D1  26/02/2022  14:30      Leverkusen       Bielefeld     3     0   H
# 6    D1  14/08/2021  17:30        Dortmund   Ein Frankfurt     5     2   H
# 108  D1  26/11/2021  19:30       Stuttgart           Mainz     2     1   H
# 104  D1  20/11/2021  14:30      M'gladbach  Greuther Furth     4     0   H
# 274  D1  23/04/2022  14:30  Greuther Furth      Leverkusen     1     4   A
#
#      HTHG  HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path3 = 'Bundesliga/D1 (3).csv'

# Cargar el archivo CSV
df3 = pd.read_csv(file_path3, sep=",")

# Mostrar las primeras filas del datas
print(df3.shape)
df3.sample(10)
# Out:
# (306, 105)
#     Div        Date   Time      HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 202  D1  27/02/2021  17:30    RB Leipzig     M'gladbach     3     2   H     0
# 31   D1  17/10/2020  14:30         Mainz     Leverkusen     0     1   A     0
# 42   D1  25/10/2020  14:30     Wolfsburg      Bielefeld     2     1   H     2
# 59   D1  07/11/2020  14:30  Union Berlin      Bielefeld     5     0   H     3
# 173  D1  06/02/2021  14:30      Freiburg       Dortmund     2     1   H     0
# 35   D1  18/10/2020  17:00    Schalke 04   Union Berlin     1     1   D     0
# 170  D1  31/01/2021  17:00     Wolfsburg       Freiburg     3     0   H     2
# 158  D1  23/01/2021  14:30         Mainz     RB Leipzig     3     2   H     2
# 193  D1  20/02/2021  17:30    Schalke 04       Dortmund     0     4   A     0
# 9    D1  25/09/2020  19:30        Hertha  Ein Frankfurt     1     3   A     0
#
#      HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# Ruta al archivo CSV
file_path4 = 'Bundesliga/D1 (4).csv'

# Cargar el archivo CSV
df4 = pd.read_csv(file_path4, sep=",")

# Mostrar las primeras filas del datas
print(df4.shape)
df4.sample(10)
# Out:
# (306, 105)
#     Div        Date   Time       HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 276  D1  13/06/2020  17:30  Bayern Munich     M'gladbach     2     1   H
# 87   D1  02/11/2019  17:30   Union Berlin         Hertha     1     0   H
# 289  D1  20/06/2020  14:30        FC Koln  Ein Frankfurt     1     1   D
# 116  D1  02/12/2019  19:30          Mainz  Ein Frankfurt     2     1   H
# 125  D1  08/12/2019  17:00  Werder Bremen      Paderborn     0     1   A
# 260  D1  03/06/2020  19:30  Werder Bremen  Ein Frankfurt     0     3   A
# 165  D1  25/01/2020  14:30     M'gladbach          Mainz     3     1   H
# 141  D1  18/12/2019  19:30       Freiburg  Bayern Munich     1     3   A
# 72   D1  25/10/2019  19:30          Mainz        FC Koln     3     1   H
# 218  D1  07/03/2020  14:30     Schalke 04     Hoffenheim     1     1   D
#
#      HTHG  HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# ...

# %%
# Concatenar los DataFrames
bundesliga = pd.concat([df,df1, df2, df3, df4])
print(bundesliga.shape)
bundesliga.sample(10)
# Out:
# (1530, 105)
#     Div        Date   Time       HomeTeam            AwayTeam  FTHG  FTAG FTR  \
# 295  D1  16/05/2021  17:00          Mainz            Dortmund     1     3   A
# 280  D1  16/06/2020  19:30       Freiburg              Hertha     2     1   H
# 288  D1  06/05/2022  19:30         Bochum           Bielefeld     2     1   H
# 145  D1  24/01/2023  19:30  Bayern Munich             FC Koln     1     1   D
# 181  D1  08/02/2020  14:30       Freiburg          Hoffenheim     1     0   H
# 142  D1  17/01/2021  14:30  Bayern Munich            Freiburg     2     1   H
# 143  D1  12/01/2024  19:30  Bayern Munich          Hoffenheim     3     0   H
# 64   D1  01/10/2022  14:30  Ein Frankfurt        Union Berlin     2     0   H
# 119  D1  07/12/2019  14:30       Dortmund  Fortuna Dusseldorf     5     0   H
# 74   D1  08/10/2022  14:30         Bochum       Ein Frankfurt     3     0   H
#
#      HTHG  HTAG HTR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  \
# ...

# %%
# Guardar como CSV
bundesliga.to_csv("bundesliga.csv", index=False)
